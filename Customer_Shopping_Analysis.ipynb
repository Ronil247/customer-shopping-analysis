# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("customer_trends.csv")

# %%
df.head()
# Out:
#    Customer_ID  Age Gender Item_Purchased  Category  Purchase_Amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         Location Size      Color  Season  Review_Rating Subscription_Status  \
# 0       Kentucky    L       Gray  Winter            3.0                 Yes
# 1          Maine    L     Maroon  Winter            3.0                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.0                 Yes
# 3   Rhode Island    M     Maroon  Spring            4.0                 Yes
# 4         Oregon    M  Turquoise  Spring            3.0                 Yes
#
#    Shipping_Type Discount_Applied Promo_Code_Used  Previous_Purchases  \
# ...

# %%
df.tail()
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  Purchase_Amount  \
# 3895         3896   40  Female         Hoodie     Clothing               28
# 3896         3897   52  Female       Backpack  Accessories               49
# 3897         3898   46  Female           Belt  Accessories               33
# 3898         3899   44  Female          Shoes     Footwear               77
# 3899         3900   52  Female        Handbag  Accessories               81
#
#         Location Size      Color  Season  Review_Rating Subscription_Status  \
# 3895    Virginia    L  Turquoise  Summer            4.2                  No
# 3896        Iowa    L      White  Spring            4.5                  No
# 3897  New Jersey    L      Green  Spring            2.9                  No
# 3898   Minnesota    S      Brown  Summer            3.8                  No
# 3899  California    M      Beige  Spring            3.1                  No
#
# ...

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Item_Purchased', 'Category',
#        'Purchase_Amount', 'Location', 'Size', 'Color', 'Season',
#        'Review_Rating', 'Subscription_Status', 'Shipping_Type',
#        'Discount_Applied', 'Promo_Code_Used', 'Previous_Purchases',
#        'Payment_Method', 'Frequency_of_Purchases'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item_Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase_Amount         3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review_Rating           3863 non-null   float64
#  11  Subscription_Status     3900 non-null   object
#  12  Shipping_Type           3900 non-null   object
#  13  Discount_Applied        3900 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID                0
# Age                        0
# Gender                     0
# Item_Purchased             0
# Category                   0
# Purchase_Amount            0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review_Rating             37
# Subscription_Status        0
# Shipping_Type              0
# Discount_Applied           0
# Promo_Code_Used            0
# Previous_Purchases         0
# Payment_Method             0
# Frequency_of_Purchases     0
# dtype: int64

# %%
df["Review_Rating"] = df["Review_Rating"].fillna(
    df["Review_Rating"].mean()
)

# %%
df["Review_Rating"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
mean_purchase = np.mean(df["Purchase_Amount"])
max_purchase = np.max(df["Purchase_Amount"])
min_purchase = np.min(df["Purchase_Amount"])

print("Mean Purchase Amount:", mean_purchase)
print("Maximum Purchase Amount:", max_purchase)
print("Minimum Purchase Amount:", min_purchase)
# Out:
# Mean Purchase Amount: 59.76435897435898
# Maximum Purchase Amount: 100
# Minimum Purchase Amount: 20

# %%
df["Category"].value_counts()
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
df.groupby("Season")["Purchase_Amount"].sum()
# Out:
# Season
# Fall      60018
# Spring    58679
# Summer    55777
# Winter    58607
# Name: Purchase_Amount, dtype: int64
